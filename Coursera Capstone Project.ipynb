# %% [markdown]
# # **SMART AI enabled Trip planner**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# Happyevents is a company in Delhi,India that manages events fo business tourists.
# The company has to put a good program, including a hotel ,a hall for meetings,
# places of landscape to visit, stores for shopping, restaurants and cafes. So this project is about taking input from a user in form of an Indian (metro) city and make a  list of places of landscape in the selected metro city, including the nearest restaurants, cafes, and shopping hangouts

# %% [markdown]
# ## **Data Description**

# %% [markdown]
# The data used in this project is provided by Foursquare location data. The data are grouped by landscape area, and each area included the information about this area and all information about restaurants, cafes, and stores which in this area.

# %% [markdown]
# ## **Table of contents**

# %% [markdown]
# #### 01- Libraries
# #### 02- Foursquare Credentials
# #### 03- Define the city and get its latitude & longitude
# #### 04- Hotels search
# #### 05- Parks search
# #### 06- Restaurants search
# #### 07- Cafeteria search
# #### 08- Shopping stores search
# #### 09- Map to visualize hotels, shopping stores and Cafeteria
# #### 10- Map to visualize Park, Restaurant and Cafeteria

# %% [markdown]
# ## **Import Libraries**

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
# !pip install folium
import folium # plotting library

# %% [markdown]
# ## **Define Foursquare Credentials**

# %%
ClIENT_ID = 'IN0FVR5XYV5JDJRQVJMP3BAX0XPFOLWK3LMJ2Z4YH0ZZXLXQ' 
ClIENT_SECRET = 'YLE4XQ4ROLZFWWKVMJQABWRM5Q0VG2YX3NYPXB3HARW2JOF0' 
VERSION = '20190714'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: IN0FVR5XYV5JDJRQVJMP3BAX0XPFOLWK3LMJ2Z4YH0ZZXLXQ
# Foursquare_Secret:YLE4XQ4ROLZFWWKVMJQABWRM5Q0VG2YX3NYPXB3HARW2JOF0

# %% [markdown]
# ## **Get the city and its latitude & longitude**

# %%
# get the city and its latitude & longitude 
city = input("Choose a city:[Delhi','Mumbai','Chennai','Kolkata\n") #Though it can hancle other cities as well,but some fields might become redundant.Take care while changing
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# Choose a city:[Delhi','Mumbai','Chennai','Kolkata
# Mumbai
# 18.9387711 72.8353355

# %% [markdown]
# ## **Search for Hotels**

# %%
# search for hotels
search_query = 'Hotel'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IN0FVR5XYV5JDJRQVJMP3BAX0XPFOLWK3LMJ2Z4YH0ZZXLXQ&client_secret=YLE4XQ4ROLZFWWKVMJQABWRM5Q0VG2YX3NYPXB3HARW2JOF0&ll=18.9387711,72.8353355&v=20190714&query=Hotel&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 2  [{'id': '4bf58dd8d48988d1f8931735', 'name': 'B...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4                                                 []    False
#
#                          id  \
# 0  4bcf4de40ffdce72215fb2c0
# 1  4bc6c48704e8b713f57f362d
# 2  4e135a03a809291902c7d32f
# 3  4cbc460f9552b60c8d81e48b
# 4  4ffaf206e4b0a0306dd1271d
#
#                                     location.address location.cc  \
# 0  26, Corner of D.N. Road and Rustom Sidhwa Marg...          IN
# 1                                       Pitha Street          IN
# 2                               26, ADI Marzban Path          IN
# 3                                                NaN          IN
# 4                                           Near CST          IN
#
#   location.city location.country                         location.crossStreet  \
# 0        Mumbai            India                                          NaN
# 1        Mumbai            India                                         Fort
# 2        Mumbai            India  Behind Cafe Universal, Ballard Estate, Fort
# 3           NaN            India                                          NaN
# 4        Mumbai            India                                          NaN
#
#    location.distance                          location.formattedAddress  \
# 0                465  [26, Corner of D.N. Road and Rustom Sidhwa Mar...
# 1                585  [Pitha Street (Fort), Mumbai 400001, Mahārāsht...
# 2                413  [26, ADI Marzban Path (Behind Cafe Universal, ...
# 3                 36                                            [India]
# 4                 84             [Near CST, Mumbai, Mahārāshtra, India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 18.93497786680689...     18.934978
# 1  [{'label': 'display', 'lat': 18.93391483135239...     18.933915
# 2  [{'label': 'display', 'lat': 18.93603902855253...     18.936039
# 3  [{'label': 'display', 'lat': 18.93897, 'lng': ...     18.938970
# 4  [{'label': 'display', 'lat': 18.93847362379592...     18.938474
#
#    location.lng location.postalCode location.state                   name  \
# 0     72.833481              400001    Mahārāshtra        Residency Hotel
# 1     72.833205              400001    Mahārāshtra           Hotel Deluxe
# 2     72.838000              400001    Mahārāshtra  Hotel Traveller’s Inn
# 3     72.835610                 NaN            NaN      City Palace Hotel
# 4     72.834599                 NaN    Mahārāshtra      Hotel City Palace
#
#      referralId
# 0  v-1563094037
# 1  v-1563094037
# 2  v-1563094037
# 3  v-1563094037
# 4  v-1563094037

# %% [markdown]
# ## **Clean Hotel Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                     name         categories  \
# 0        Residency Hotel              Hotel
# 1           Hotel Deluxe  Indian Restaurant
# 2  Hotel Traveller’s Inn    Bed & Breakfast
# 3      City Palace Hotel              Hotel
# 4      Hotel City Palace               None
#
#                                              address  cc    city country  \
# 0  26, Corner of D.N. Road and Rustom Sidhwa Marg...  IN  Mumbai   India
# 1                                       Pitha Street  IN  Mumbai   India
# 2                               26, ADI Marzban Path  IN  Mumbai   India
# 3                                                NaN  IN     NaN   India
# 4                                           Near CST  IN  Mumbai   India
#
#                                    crossStreet  distance  \
# 0                                          NaN       465
# 1                                         Fort       585
# 2  Behind Cafe Universal, Ballard Estate, Fort       413
# 3                                          NaN        36
# 4                                          NaN        84
#
#                                     formattedAddress  \
# 0  [26, Corner of D.N. Road and Rustom Sidhwa Mar...
# 1  [Pitha Street (Fort), Mumbai 400001, Mahārāsht...
# 2  [26, ADI Marzban Path (Behind Cafe Universal, ...
# 3                                            [India]
# 4             [Near CST, Mumbai, Mahārāshtra, India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 18.93497786680689...  18.934978  72.833481
# 1  [{'label': 'display', 'lat': 18.93391483135239...  18.933915  72.833205
# 2  [{'label': 'display', 'lat': 18.93603902855253...  18.936039  72.838000
# 3  [{'label': 'display', 'lat': 18.93897, 'lng': ...  18.938970  72.835610
# 4  [{'label': 'display', 'lat': 18.93847362379592...  18.938474  72.834599
#
#   postalCode        state                        id
# 0     400001  Mahārāshtra  4bcf4de40ffdce72215fb2c0
# 1     400001  Mahārāshtra  4bc6c48704e8b713f57f362d
# 2     400001  Mahārāshtra  4e135a03a809291902c7d32f
# 3        NaN          NaN  4cbc460f9552b60c8d81e48b
# 4        NaN  Mahārāshtra  4ffaf206e4b0a0306dd1271d

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_dataframe
# Out:
#                         name                                categories  \
# 0            Residency Hotel                                     Hotel
# 1               Hotel Deluxe                         Indian Restaurant
# 2      Hotel Traveller’s Inn                           Bed & Breakfast
# 3          City Palace Hotel                                     Hotel
# 4          Hotel City Palace                                      None
# 5                sheel hotel                                     Hotel
# 6              Hotel Windsor                                    Hostel
# 7               hotel kalapi                                     Motel
# 8        Hotel Landmark Fort                           Bed & Breakfast
# 9         Colaba Grand Hotel                                 Hotel Bar
# 10      Hotel Fountain Plaza                         Indian Restaurant
# 11     Hotel Landmark Annexe                                     Hotel
# 12        Hotel Ankitakshita                                     Hotel
# 13            Hotel Arkshita                               Snack Place
# 14        Hotel Anand Bhuvan                      Fast Food Restaurant
# 15              Hotel Ashoka                         Indian Restaurant
# 16              Hotel Outram                                     Hotel
# 17             Hotel Dolphin                                     Hotel
# 18             Welcome Hotel                                     Motel
# 19     landmark hotel mumbai  Residential Building (Apartment / Condo)
# 20    hotel golden palm fort                                Hotel Pool
# 21               Hotel Grant                                     Hotel
# 22      Hotel Fountain Plaza                         Indian Restaurant
# 23            Hotel Oriental                                  Tea Room
# 24        Hotel Geeta Bhavan                         Indian Restaurant
# 25  A.k. International Hotel                                     Hotel
# 26         Hotel Grant House                                      None
# 27             hotel westend                         Indian Restaurant
# 28          Hotel New Bengal                                     Hotel
# 29              Deluxe Hotel                       Housing Development
#
#                                               address  cc    city country  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  IN  Mumbai   India
# 1                                        Pitha Street  IN  Mumbai   India
# 2                                26, ADI Marzban Path  IN  Mumbai   India
# 3                                                 NaN  IN     NaN   India
# 4                                            Near CST  IN  Mumbai   India
# 5                                                 NaN  IN     NaN   India
# 6                                          Kumptha 10  IN  Mumbai   India
# 7                                                 NaN  IN     NaN   India
# 8                                  249 P D Mello Road  IN  Mumbai   India
# 9                                              Colaba  IN  Mumbai   India
# 10            panthaky house, Raghunath dadaji street  IN  Mumbai   India
# 11                                                NaN  IN  Mumbai   India
# 12                                                NaN  IN  Mumbai   India
# 13                                                NaN  IN     NaN   India
# 14                  Opposite Shahid bhagat Singh Road  IN  Mumbai   India
# 15                                                NaN  IN     NaN   India
# 16                                                NaN  IN     NaN   India
# 17                                       327,SBS Road  IN  Mumbai   India
# 18                        257 Shahid Bhagat Singh Rd.  IN  Mumbai   India
# 19                                                NaN  IN     NaN   India
# 20                                               Fort  IN  Mumbai   India
# 21                                                NaN  IN  Mumbai   India
# 22                                                NaN  IN     NaN   India
# 23                                                NaN  IN     NaN   India
# 24                                                NaN  IN     NaN   India
# 25                                                NaN  IN     NaN   India
# 26                                  Mata Ramabai Marg  IN  Mumbai   India
# 27                                Opp Bombay Hospital  IN     NaN   India
# 28                                   Doctor D.N. Road  IN  Mumbai   India
# 29                       287 Shahid Bhagat Singh Road  IN    Fort   India
#
#                                     crossStreet  distance  \
# 0                                           NaN       465
# 1                                          Fort       585
# 2   Behind Cafe Universal, Ballard Estate, Fort       413
# 3                                           NaN        36
# 4                                           NaN        84
# 5                                           NaN        74
# 6                                           NaN       383
# 7                                           NaN       267
# 8                                Near GPO, Fort       281
# 9                                           NaN       153
# 10                              Kalaghoda, Fort       371
# 11                                          NaN       378
# 12                                          NaN       390
# 13                                          NaN       405
# 14                                         Fort       414
# 15                                          NaN       450
# 16                                          NaN       461
# 17                                         Fort       497
# 18                                     Near GPO       253
# 19                                          NaN       305
# 20                                          NaN       635
# 21                                          NaN       665
# 22                                          NaN       642
# 23                                          NaN       628
# 24                                          NaN      1078
# 25                                          NaN       419
# 26                                          NaN       718
# 27                                       Mumbai       834
# 28                                          NaN       787
# 29                                          NaN       405
#
#                                      formattedAddress  \
# 0   [26, Corner of D.N. Road and Rustom Sidhwa Mar...
# 1   [Pitha Street (Fort), Mumbai 400001, Mahārāsht...
# 2   [26, ADI Marzban Path (Behind Cafe Universal, ...
# 3                                             [India]
# 4              [Near CST, Mumbai, Mahārāshtra, India]
# 5                                             [India]
# 6            [Kumptha 10, Mumbai, Mahārāshtra, India]
# 7                                             [India]
# 8   [249 P D Mello Road (Near GPO, Fort), Mumbai 4...
# 9                [Colaba, Mumbai, Mahārāshtra, India]
# 10  [panthaky house, Raghunath dadaji street (Kala...
# 11                [Mumbai 400001, Mahārāshtra, India]
# 12                [Mumbai 400023, Mahārāshtra, India]
# 13                                            [India]
# 14  [Opposite Shahid bhagat Singh Road (Fort), Mum...
# 15                                            [India]
# 16                                            [India]
# 17  [327,SBS Road (Fort), Mumbai, Mahārāshtra, India]
# 18  [257 Shahid Bhagat Singh Rd. (Near GPO), Mumba...
# 19                                            [India]
# 20                 [Fort, Mumbai, Mahārāshtra, India]
# 21                       [Mumbai, Mahārāshtra, India]
# 22                                            [India]
# 23                                            [India]
# 24                                            [India]
# 25                                            [India]
# 26  [Mata Ramabai Marg, Mumbai 400001, Mahārāshtra...
# 27              [Opp Bombay Hospital (Mumbai), India]
# 28  [Doctor D.N. Road, Mumbai 400001, Mahārāshtra,...
# 29  [287 Shahid Bhagat Singh Road, Fort 400001, Ma...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 18.93497786680689...  18.934978  72.833481
# 1   [{'label': 'display', 'lat': 18.93391483135239...  18.933915  72.833205
# 2   [{'label': 'display', 'lat': 18.93603902855253...  18.936039  72.838000
# 3   [{'label': 'display', 'lat': 18.93897, 'lng': ...  18.938970  72.835610
# 4   [{'label': 'display', 'lat': 18.93847362379592...  18.938474  72.834599
# 5   [{'label': 'display', 'lat': 18.93821144054106...  18.938211  72.835725
# 6   [{'label': 'display', 'lat': 18.93680816877854...  18.936808  72.838327
# 7   [{'label': 'display', 'lat': 18.93818396949494...  18.938184  72.837802
# 8   [{'label': 'display', 'lat': 18.93852795728219...  18.938528  72.837998
# 9   [{'label': 'display', 'lat': 18.93965642004740...  18.939656  72.836457
# 10  [{'label': 'display', 'lat': 18.93567108713781...  18.935671  72.834030
# 11  [{'label': 'display', 'lat': 18.93803, 'lng': ...  18.938030  72.838844
# 12  [{'label': 'display', 'lat': 18.935698, 'lng':...  18.935698  72.837123
# 13  [{'label': 'display', 'lat': 18.93564657541938...  18.935647  72.837311
# 14  [{'label': 'display', 'lat': 18.93534530059420...  18.935345  72.836884
# 15  [{'label': 'display', 'lat': 18.94274063722833...  18.942741  72.834501
# 16  [{'label': 'display', 'lat': 18.936418, 'lng':...  18.936418  72.831732
# 17  [{'label': 'display', 'lat': 18.9345666, 'lng'...  18.934567  72.836942
# 18  [{'label': 'display', 'lat': 18.93770343097870...  18.937703  72.837467
# 19  [{'label': 'display', 'lat': 18.93846538979575...  18.938465  72.838217
# 20  [{'label': 'display', 'lat': 18.93310332676041...  18.933103  72.834628
# 21  [{'label': 'display', 'lat': 18.935748, 'lng':...  18.935748  72.840787
# 22  [{'label': 'display', 'lat': 18.933003, 'lng':...  18.933003  72.835396
# 23  [{'label': 'display', 'lat': 18.93355494517345...  18.933555  72.837617
# 24  [{'label': 'display', 'lat': 18.94581829920161...  18.945818  72.828304
# 25  [{'label': 'display', 'lat': 18.935867, 'lng':...  18.935867  72.837875
# 26  [{'label': 'display', 'lat': 18.94520678708145...  18.945207  72.834773
# 27  [{'label': 'display', 'lat': 18.94073486328125...  18.940735  72.827690
# 28  [{'label': 'display', 'lat': 18.94572210870355...  18.945722  72.833936
# 29  [{'label': 'display', 'lat': 18.93569008131626...  18.935690  72.837398
#
#    postalCode        state                        id
# 0      400001  Mahārāshtra  4bcf4de40ffdce72215fb2c0
# 1      400001  Mahārāshtra  4bc6c48704e8b713f57f362d
# 2      400001  Mahārāshtra  4e135a03a809291902c7d32f
# 3         NaN          NaN  4cbc460f9552b60c8d81e48b
# 4         NaN  Mahārāshtra  4ffaf206e4b0a0306dd1271d
# 5         NaN          NaN  5321eed6498e273e35971c04
# 6         NaN  Mahārāshtra  511cfaa2e4b0d31a018b152b
# 7         NaN          NaN  4f3e6f67e4b090fd1717b9ea
# 8      400001  Mahārāshtra  5121e326e4b0293c8253ab3b
# 9         NaN  Mahārāshtra  4ecc40cb9adf1839a0f164d1
# 10        NaN  Mahārāshtra  4d31c9a072a8b1f7878797d0
# 11     400001  Mahārāshtra  5a84a6e3d1a40227bf2ea3c5
# 12     400023  Mahārāshtra  5ac2ef59bed4830d66788006
# 13        NaN          NaN  4ec8942849010f98cde5bc97
# 14     400001  Mahārāshtra  5010ebebe4b06bc0bc4bb05e
# 15        NaN          NaN  54932af2498e3b3acb749ec6
# 16        NaN          NaN  4d0c40f2e0b98cfa3a28d493
# 17        NaN  Mahārāshtra  4e93f5fc49015a5ff4680d44
# 18        NaN  Mahārāshtra  4d08e39984ec224b880e2c62
# 19        NaN          NaN  5306c6e9498e2adaad0066a8
# 20        NaN  Mahārāshtra  52f865d3498e92ebee122292
# 21        NaN  Mahārāshtra  4de059ccc65bcc724f3e1a71
# 22        NaN          NaN  52aeb47b498e11755d8c2cce
# 23        NaN          NaN  4eccd81ab6344934dd17b561
# 24        NaN          NaN  4bf60556bfeac9281dc29336
# 25        NaN          NaN  5ae8a6b03ba767002cd296da
# 26     400001  Mahārāshtra  4dccc92fe4cd130e163eb5a7
# 27        NaN          NaN  51d69557498ebc0232f456b0
# 28     400001  Mahārāshtra  4b0587caf964a520d8a122e3
# 29     400001  Mahārāshtra  518534eb498edeec015edb68

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                      name            categories  \
# 0         Residency Hotel                 Hotel
# 1            Hotel Deluxe     Indian Restaurant
# 2   Hotel Traveller’s Inn       Bed & Breakfast
# 8     Hotel Landmark Fort       Bed & Breakfast
# 14     Hotel Anand Bhuvan  Fast Food Restaurant
# 28       Hotel New Bengal                 Hotel
# 29           Deluxe Hotel   Housing Development
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 1                                        Pitha Street  18.933915  72.833205
# 2                                26, ADI Marzban Path  18.936039  72.838000
# 8                                  249 P D Mello Road  18.938528  72.837998
# 14                  Opposite Shahid bhagat Singh Road  18.935345  72.836884
# 28                                   Doctor D.N. Road  18.945722  72.833936
# 29                       287 Shahid Bhagat Singh Road  18.935690  72.837398
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 1      400001  Mahārāshtra
# 2      400001  Mahārāshtra
# 8      400001  Mahārāshtra
# 14     400001  Mahārāshtra
# 28     400001  Mahārāshtra
# 29     400001  Mahārāshtra

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                 name categories  \
# 0    Residency Hotel      Hotel
# 28  Hotel New Bengal      Hotel
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 28                                   Doctor D.N. Road  18.945722  72.833936
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 28     400001  Mahārāshtra

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                 name categories  \
# 0    Residency Hotel      Hotel
# 28  Hotel New Bengal      Hotel
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 28                                   Doctor D.N. Road  18.945722  72.833936
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 28     400001  Mahārāshtra

# %% [markdown]
# ## **Search for Parks**

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IN0FVR5XYV5JDJRQVJMP3BAX0XPFOLWK3LMJ2Z4YH0ZZXLXQ&client_secret=YLE4XQ4ROLZFWWKVMJQABWRM5Q0VG2YX3NYPXB3HARW2JOF0&ll=18.9387711,72.8353355&v=20190714&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...    False
# 3  [{'id': '4f2a210c4b9023bd5841ed28', 'name': 'H...    False
# 4  [{'id': '5267e4d9e4b0ec79466e48c6', 'name': 'C...    False
#
#                          id                          location.address  \
# 0  4c9174ec238c6dcb067ec055                           Nepean Sea Road
# 1  511e3da9e4b092d8057a44b6  Breach Candy, Behind American Counsulate
# 2  4c84af7ed34ca14342c74080                   in High Street Phoenix,
# 3  4c1e0f17b4e62d7ff1a2dd93                          Near Imax Adlabs
# 4  52f2771d11d2afc107a8206d                       1176 Kingwood Drive
#
#   location.cc location.city location.country  location.crossStreet  \
# 0          IN        Mumbai            India                   NaN
# 1          IN        Mumbai            India  Bhulabhai Desai Road
# 2          IN        Mumbai            India                   NaN
# 3          IN        Mumbai            India                Wadala
# 4          IN          Avon            India                   NaN
#
#    location.distance                          location.formattedAddress  \
# 0               4301  [Nepean Sea Road, Mumbai 400006, Mahārāshtra, ...
# 1               2930  [Breach Candy, Behind American Counsulate (Bhu...
# 2               6544  [in High Street Phoenix,, Mumbai, Mahārāshtra,...
# 3              10956  [Near Imax Adlabs (Wadala), Mumbai 400037, Mah...
# 4               1230  [1176 Kingwood Drive, Avon 46123, Indiana, India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 18.95751519120163...     18.957515
# 1  [{'label': 'display', 'lat': 18.91486679408915...     18.914867
# 2  [{'label': 'display', 'lat': 18.99698589447507...     18.996986
# 3  [{'label': 'display', 'lat': 19.02767011619118...     19.027670
# 4  [{'label': 'display', 'lat': 18.94980408771263...     18.949804
#
#    location.lng location.postalCode location.state  \
# 0     72.799614              400006    Mahārāshtra
# 1     72.823688              400026    Mahārāshtra
# 2     72.826677                 NaN    Mahārāshtra
# 3     72.880010              400037    Mahārāshtra
# 4     72.834699               46123        Indiana
#
#                               name    referralId venuePage.id
# 0               Priyadarshini Park  v-1563094038          NaN
# 1  Harish Mahindra Children's Park  v-1563094038          NaN
# 2                      Park Avenue  v-1563094038          NaN
# 3                      Bhakti Park  v-1563094038          NaN
# 4        Traditions at Reagan Park  v-1563094038          NaN

# %% [markdown]
# ## **Clean Park Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                               name           categories  \
# 0               Priyadarshini Park                 Park
# 1  Harish Mahindra Children's Park                 Park
# 2                      Park Avenue       Clothing Store
# 3                      Bhakti Park  Housing Development
# 4        Traditions at Reagan Park           Conference
#
#                                     address  cc    city country  \
# 0                           Nepean Sea Road  IN  Mumbai   India
# 1  Breach Candy, Behind American Counsulate  IN  Mumbai   India
# 2                   in High Street Phoenix,  IN  Mumbai   India
# 3                          Near Imax Adlabs  IN  Mumbai   India
# 4                       1176 Kingwood Drive  IN    Avon   India
#
#             crossStreet  distance  \
# 0                   NaN      4301
# 1  Bhulabhai Desai Road      2930
# 2                   NaN      6544
# 3                Wadala     10956
# 4                   NaN      1230
#
#                                     formattedAddress  \
# 0  [Nepean Sea Road, Mumbai 400006, Mahārāshtra, ...
# 1  [Breach Candy, Behind American Counsulate (Bhu...
# 2  [in High Street Phoenix,, Mumbai, Mahārāshtra,...
# 3  [Near Imax Adlabs (Wadala), Mumbai 400037, Mah...
# 4  [1176 Kingwood Drive, Avon 46123, Indiana, India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 18.95751519120163...  18.957515  72.799614
# 1  [{'label': 'display', 'lat': 18.91486679408915...  18.914867  72.823688
# 2  [{'label': 'display', 'lat': 18.99698589447507...  18.996986  72.826677
# 3  [{'label': 'display', 'lat': 19.02767011619118...  19.027670  72.880010
# 4  [{'label': 'display', 'lat': 18.94980408771263...  18.949804  72.834699
#
#   postalCode        state                        id
# 0     400006  Mahārāshtra  4c9174ec238c6dcb067ec055
# 1     400026  Mahārāshtra  511e3da9e4b092d8057a44b6
# 2        NaN  Mahārāshtra  4c84af7ed34ca14342c74080
# 3     400037  Mahārāshtra  4c1e0f17b4e62d7ff1a2dd93
# 4      46123      Indiana  52f2771d11d2afc107a8206d

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                name                                categories  \
# 0                Priyadarshini Park                                      Park
# 1   Harish Mahindra Children's Park                                      Park
# 2                       Park Avenue                            Clothing Store
# 3                       Bhakti Park                       Housing Development
# 4         Traditions at Reagan Park                                Conference
# 5              Hotel Residency Park                                     Hotel
# 6          Peninsula Corporate Park                                  Building
# 7                       Rivali Park                        Real Estate Office
# 8                       Park Avenue                               Men's Store
# 9              Hotel Residency Park                                     Hotel
# 10     Bhakti Park Monorail Station                        Light Rail Station
# 11                 One Avighna Park                       Housing Development
# 12                     Badhwar Park                       Housing Development
# 13                     Badhwar Park                              Neighborhood
# 14              Kanha National Park                      Other Great Outdoors
# 15                     Park Shilton                                Restaurant
# 16                     Badhwar Park  Residential Building (Apartment / Condo)
# 17                     Traffic Park                                      Park
# 18                        Park View  Residential Building (Apartment / Condo)
# 19                       Oomer Park  Residential Building (Apartment / Condo)
# 20                      saifee park  Residential Building (Apartment / Condo)
# 21                        Hill Park  Residential Building (Apartment / Condo)
# 22                Kamala Nehru Park                       Monument / Landmark
# 23      China Garden Shivaji Park ¤                        Chinese Restaurant
# 24             Harish Mahindra Park                                Playground
# 25                  Land's End Park                                      Park
# 26              Saifee Burhani Park  Residential Building (Apartment / Condo)
# 27                Park Avenue Women                             Women's Store
# 28                      Park Avenue                            Clothing Store
# 29                         PDP park                              Soccer Field
#
#                                               address  \
# 0                                     Nepean Sea Road
# 1            Breach Candy, Behind American Counsulate
# 2                             in High Street Phoenix,
# 3                                    Near Imax Adlabs
# 4                                 1176 Kingwood Drive
# 5                                                 NaN
# 6                                         Lower Parel
# 7   Rivali Park, Western Express Highway,Borivali ...
# 8   Shop No. 32/34, Churchgate House, Veer Nariman...
# 9                                                 NaN
# 10                                        Bhakti Park
# 11                          Mahadev Palav Marg, Parel
# 12                                     Wodehouse Road
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                             Colaba
# 17          Cooperage Rd, Colaba, Mumbai, Maharashtra
# 18                                                NaN
# 19                               Bhulabhai Desai Road
# 20                                                NaN
# 21                                       Malabar Hill
# 22                                      B G Kher Road
# 23             Cadell Road, Opposite Catering College
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                            Sky Zone, phoenix mills
# 29                                     Nepeansea road
#
#                   crossStreet        lat        lng postalCode           state
# 0                         NaN  18.957515  72.799614     400006     Mahārāshtra
# 1        Bhulabhai Desai Road  18.914867  72.823688     400026     Mahārāshtra
# 2                         NaN  18.996986  72.826677        NaN     Mahārāshtra
# 3                      Wadala  19.027670  72.880010     400037     Mahārāshtra
# 4                         NaN  18.949804  72.834699      46123         Indiana
# 5                         NaN  18.953255  72.835320        NaN             NaN
# 6                    G K Marg  18.998626  72.825408     400013     Mahārāshtra
# 7                         NaN  18.929599  72.828181     400066     Mahārāshtra
# 8    Shahid Bhagat Singh Road  18.920214  72.830151     400001     Mahārāshtra
# 9                         NaN  18.953120  72.835175     400003     Mahārāshtra
# 10                     Wadala  19.029101  72.877627        NaN     Mahārāshtra
# 11  Mahadev Palav Marg, Parel  18.994041  72.834806     400012     Mahārāshtra
# 12               Cuffe Parade  18.919160  72.826648        NaN     Mahārāshtra
# 13                        NaN  18.921100  72.827300        NaN             NaN
# 14                        NaN  18.923037  72.822986        NaN  Madhya Pradesh
# 15                        NaN  18.965763  72.819282        NaN             NaN
# 16                        NaN  18.918839  72.828051     400005     Mahārāshtra
# 17                        NaN  18.918844  72.825933        NaN     Mahārāshtra
# 18                        NaN  18.973326  72.823997        NaN             NaN
# 19                        NaN  18.966110  72.805144     400026     Mahārāshtra
# 20                        NaN  18.972489  72.839654        NaN             NaN
# 21              A.G.Bell Marg  18.951897  72.799129     400006     Mahārāshtra
# 22                        NaN  18.949898  72.801318    400 026     Mahārāshtra
# 23                        NaN  19.023244  72.835148        NaN     Mahārāshtra
# 24                        NaN  18.967493  72.803746        NaN             NaN
# 25                        NaN  18.916561  72.816366        NaN             NaN
# 26                        NaN  18.972708  72.842735        NaN             NaN
# 27                        NaN  18.995185  72.824560        NaN             NaN
# 28        Senapati bapat marg  18.995051  72.823619        NaN     Mahārāshtra
# 29                        NaN  18.962519  72.801455        NaN             NaN

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                name                                categories  \
# 1   Harish Mahindra Children's Park                                      Park
# 3                       Bhakti Park                       Housing Development
# 6          Peninsula Corporate Park                                  Building
# 8                       Park Avenue                               Men's Store
# 11                 One Avighna Park                       Housing Development
# 21                        Hill Park  Residential Building (Apartment / Condo)
#
#                                               address  \
# 1            Breach Candy, Behind American Counsulate
# 3                                    Near Imax Adlabs
# 6                                         Lower Parel
# 8   Shop No. 32/34, Churchgate House, Veer Nariman...
# 11                          Mahadev Palav Marg, Parel
# 21                                       Malabar Hill
#
#                   crossStreet        lat        lng postalCode        state
# 1        Bhulabhai Desai Road  18.914867  72.823688     400026  Mahārāshtra
# 3                      Wadala  19.027670  72.880010     400037  Mahārāshtra
# 6                    G K Marg  18.998626  72.825408     400013  Mahārāshtra
# 8    Shahid Bhagat Singh Road  18.920214  72.830151     400001  Mahārāshtra
# 11  Mahadev Palav Marg, Parel  18.994041  72.834806     400012  Mahārāshtra
# 21              A.G.Bell Marg  18.951897  72.799129     400006  Mahārāshtra

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                               name categories  \
# 1  Harish Mahindra Children's Park       Park
#
#                                     address           crossStreet        lat  \
# 1  Breach Candy, Behind American Counsulate  Bhulabhai Desai Road  18.914867
#
#          lng postalCode        state
# 1  72.823688     400026  Mahārāshtra

# %% [markdown]
# ## **Search for Restaurants**

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IN0FVR5XYV5JDJRQVJMP3BAX0XPFOLWK3LMJ2Z4YH0ZZXLXQ&client_secret=YLE4XQ4ROLZFWWKVMJQABWRM5Q0VG2YX3NYPXB3HARW2JOF0&ll=18.9387711,72.8353355&v=20190714&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 4                                                 []    False
#
#                          id    location.address location.cc location.city  \
# 0  4e4c0a4122713bd908c641ff        Opposite GPO          IN        Mumbai
# 1  5263f0f5498edc1ad5f3270f  Near GPO, Fort, VT          IN        Mumbai
# 2  4c09449eed2595217aee1256   Veer Nariman Road          IN        Mumbai
# 3  4f489f23e4b018635344413a   Opp. Metro Cinema          IN        Mumbai
# 4  4e7c3bdf52b10564f7f6fd20                 NaN          IN        Mumbai
#
#   location.country                location.crossStreet  location.distance  \
# 0            India                      Ballard Estate                280
# 1            India                S. Bhagat Singh Road                260
# 2            India  Next to Vodafone Store, Churchgate               1082
# 3            India                        Marine Lines               1007
# 4            India                                 NaN                 53
#
#                            location.formattedAddress  \
# 0  [Opposite GPO (Ballard Estate), Mumbai, Mahārā...
# 1  [Near GPO, Fort, VT (S. Bhagat Singh Road), Mu...
# 2  [Veer Nariman Road (Next to Vodafone Store, Ch...
# 3  [Opp. Metro Cinema (Marine Lines), Mumbai, Mah...
# 4                       [Mumbai, Mahārāshtra, India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 18.93816453050136...     18.938165
# 1  [{'label': 'display', 'lat': 18.93797448587734...     18.937974
# 2  [{'label': 'display', 'lat': 18.93317339191467...     18.933173
# 3  [{'label': 'display', 'lat': 18.94289961203775...     18.942900
# 4  [{'label': 'display', 'lat': 18.93835719323860...     18.938357
#
#    location.lng location.postalCode location.state  \
# 0     72.837917                 NaN    Mahārāshtra
# 1     72.837663              400001    Mahārāshtra
# 2     72.826929              400023    Mahārāshtra
# 3     72.826820                 NaN    Mahārāshtra
# 4     72.835073                 NaN    Mahārāshtra
#
#                                 name    referralId
# 0                 Farhang Restaurant  v-1563094040
# 1  Nanumal Bhojraj Restaurant - Fort  v-1563094040
# 2        Stadium Restaurant & Stores  v-1563094040
# 3        Panchratna restaurant & bar  v-1563094040
# 4               Sai Pooja Restaurant  v-1563094040

# %% [markdown]
# ## **Clean Restaurant Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                 name         categories             address  \
# 0                 Farhang Restaurant         Steakhouse        Opposite GPO
# 1  Nanumal Bhojraj Restaurant - Fort  Indian Restaurant  Near GPO, Fort, VT
# 2        Stadium Restaurant & Stores  Indian Restaurant   Veer Nariman Road
# 3        Panchratna restaurant & bar  Indian Restaurant   Opp. Metro Cinema
# 4               Sai Pooja Restaurant               None                 NaN
#
#    cc    city country                         crossStreet  distance  \
# 0  IN  Mumbai   India                      Ballard Estate       280
# 1  IN  Mumbai   India                S. Bhagat Singh Road       260
# 2  IN  Mumbai   India  Next to Vodafone Store, Churchgate      1082
# 3  IN  Mumbai   India                        Marine Lines      1007
# 4  IN  Mumbai   India                                 NaN        53
#
#                                     formattedAddress  \
# 0  [Opposite GPO (Ballard Estate), Mumbai, Mahārā...
# 1  [Near GPO, Fort, VT (S. Bhagat Singh Road), Mu...
# 2  [Veer Nariman Road (Next to Vodafone Store, Ch...
# 3  [Opp. Metro Cinema (Marine Lines), Mumbai, Mah...
# 4                       [Mumbai, Mahārāshtra, India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 18.93816453050136...  18.938165  72.837917
# 1  [{'label': 'display', 'lat': 18.93797448587734...  18.937974  72.837663
# 2  [{'label': 'display', 'lat': 18.93317339191467...  18.933173  72.826929
# 3  [{'label': 'display', 'lat': 18.94289961203775...  18.942900  72.826820
# 4  [{'label': 'display', 'lat': 18.93835719323860...  18.938357  72.835073
#
#   postalCode        state                        id
# 0        NaN  Mahārāshtra  4e4c0a4122713bd908c641ff
# 1     400001  Mahārāshtra  5263f0f5498edc1ad5f3270f
# 2     400023  Mahārāshtra  4c09449eed2595217aee1256
# 3        NaN  Mahārāshtra  4f489f23e4b018635344413a
# 4        NaN  Mahārāshtra  4e7c3bdf52b10564f7f6fd20

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                           name                     categories  \
# 0                           Farhang Restaurant                     Steakhouse
# 1            Nanumal Bhojraj Restaurant - Fort              Indian Restaurant
# 2                  Stadium Restaurant & Stores              Indian Restaurant
# 3                  Panchratna restaurant & bar              Indian Restaurant
# 4                         Sai Pooja Restaurant                           None
# 5                         Iran Like Restaurant              Indian Restaurant
# 6                      New Majestic Restaurant              Indian Restaurant
# 7                            Poonam Restaurant                     Restaurant
# 8                              Aram Restaurant               Asian Restaurant
# 9                            Canara Restaurant              Indian Restaurant
# 10  Nanumal Bhojraj Restaurant - Masjid Bunder              Indian Restaurant
# 11                          Kalpana restaurant                           None
# 12                         National Restaurant                           Food
# 13                          Kamat's Restaurant              Indian Restaurant
# 14                Fountain Sizzlers Restaurant              Indian Restaurant
# 15                          Gulshan Restaurant              Indian Restaurant
# 16                Sind Punjab Bar & Restaurant                     Restaurant
# 17                   Mangalore naaz Restaurant               Asian Restaurant
# 18                     Golden Wheel Restaurant                     Restaurant
# 19                    Anubhav Restaurant & Bar              Indian Restaurant
# 20                           Bombay Restaurant              Indian Restaurant
# 21                      Excellensea Restaurant                      BBQ Joint
# 22               Bademiya The Kabab Restaurant             Mughlai Restaurant
# 23                           Khyber Restaurant              Indian Restaurant
# 24                       queen mary restaurant                           Café
# 25                      Royal China Restaurant           Cantonese Restaurant
# 26                       Samrat Veg Restaurant  Vegetarian / Vegan Restaurant
# 27                          Ustaadi Restaurant                         Lounge
# 28                         Goodluck Restaurant                           None
# 29                         Brighton Restaurant                     Restaurant
#
#                                               address        lat        lng  \
# 0                                        Opposite GPO  18.938165  72.837917
# 1                                  Near GPO, Fort, VT  18.937974  72.837663
# 2                                   Veer Nariman Road  18.933173  72.826929
# 3                                   Opp. Metro Cinema  18.942900  72.826820
# 4                                                 NaN  18.938357  72.835073
# 5                         Palton Road, Near Haj House  18.945343  72.836809
# 6                                             Opp CST  18.938972  72.835517
# 7                                                 NaN  18.939225  72.835707
# 8                           Capitol building, DN Road  18.939543  72.834495
# 9                                                 NaN  18.936847  72.837525
# 10  Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 11                                                Gpo  18.937489  72.836157
# 12                                    opp fort market  18.935112  72.836896
# 13                        Opp. Electric House, Colaba  18.921570  72.831004
# 14                             57 Mahatma Gandhi Road  18.931366  72.831462
# 15                                                NaN  18.938199  72.837764
# 16                        263, SBS Road, Fort, Mumbai  18.937048  72.837381
# 17                                                NaN  18.937245  72.837606
# 18                                            Girgaon  18.954636  72.819690
# 19                                                NaN  18.936497  72.837586
# 20                                                NaN  18.935902  72.834426
# 21                                          Mint Road  18.935266  72.837240
# 22                                    Horniman Circle  18.931330  72.834983
# 23                   Kalaghoda, 145 Mahatma Gandhi Rd  18.928134  72.831541
# 24                                                NaN  18.969932  72.835495
# 25                                                NaN  18.937876  72.831005
# 26                                    J. D. Tata Road  18.930674  72.826320
# 27                          B Block, Sitaram Building  18.945482  72.834270
# 28                                                NaN  18.935578  72.837357
# 29                                                NaN  18.935007  72.833687
#
#    postalCode        state
# 0         NaN  Mahārāshtra
# 1      400001  Mahārāshtra
# 2      400023  Mahārāshtra
# 3         NaN  Mahārāshtra
# 4         NaN  Mahārāshtra
# 5      400001  Mahārāshtra
# 6         NaN  Mahārāshtra
# 7         NaN          NaN
# 8         NaN  Mahārāshtra
# 9         NaN          NaN
# 10     400009  Mahārāshtra
# 11        NaN  Mahārāshtra
# 12     400001  Mahārāshtra
# 13        NaN  Mahārāshtra
# 14    400 023  Mahārāshtra
# 15     400001  Mahārāshtra
# 16        NaN          NaN
# 17        NaN          NaN
# 18        NaN  Mahārāshtra
# 19     400001  Mahārāshtra
# 20        NaN  Mahārāshtra
# 21     400001  Mahārāshtra
# 22     400002  Mahārāshtra
# 23    400 023  Mahārāshtra
# 24        NaN          NaN
# 25        NaN          NaN
# 26    400 020  Mahārāshtra
# 27     400001  Mahārāshtra
# 28        NaN  Mahārāshtra
# 29        NaN          NaN

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                           name                     categories  \
# 1            Nanumal Bhojraj Restaurant - Fort              Indian Restaurant
# 2                  Stadium Restaurant & Stores              Indian Restaurant
# 5                         Iran Like Restaurant              Indian Restaurant
# 10  Nanumal Bhojraj Restaurant - Masjid Bunder              Indian Restaurant
# 12                         National Restaurant                           Food
# 14                Fountain Sizzlers Restaurant              Indian Restaurant
# 21                      Excellensea Restaurant                      BBQ Joint
# 22               Bademiya The Kabab Restaurant             Mughlai Restaurant
# 23                           Khyber Restaurant              Indian Restaurant
# 26                       Samrat Veg Restaurant  Vegetarian / Vegan Restaurant
# 27                          Ustaadi Restaurant                         Lounge
#
#                                               address        lat        lng  \
# 1                                  Near GPO, Fort, VT  18.937974  72.837663
# 2                                   Veer Nariman Road  18.933173  72.826929
# 5                         Palton Road, Near Haj House  18.945343  72.836809
# 10  Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 12                                    opp fort market  18.935112  72.836896
# 14                             57 Mahatma Gandhi Road  18.931366  72.831462
# 21                                          Mint Road  18.935266  72.837240
# 22                                    Horniman Circle  18.931330  72.834983
# 23                   Kalaghoda, 145 Mahatma Gandhi Rd  18.928134  72.831541
# 26                                    J. D. Tata Road  18.930674  72.826320
# 27                          B Block, Sitaram Building  18.945482  72.834270
#
#    postalCode        state
# 1      400001  Mahārāshtra
# 2      400023  Mahārāshtra
# 5      400001  Mahārāshtra
# 10     400009  Mahārāshtra
# 12     400001  Mahārāshtra
# 14    400 023  Mahārāshtra
# 21     400001  Mahārāshtra
# 22     400002  Mahārāshtra
# 23    400 023  Mahārāshtra
# 26    400 020  Mahārāshtra
# 27     400001  Mahārāshtra

# %% [markdown]
# ## **Search for Cafeteria**

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IN0FVR5XYV5JDJRQVJMP3BAX0XPFOLWK3LMJ2Z4YH0ZZXLXQ&client_secret=YLE4XQ4ROLZFWWKVMJQABWRM5Q0VG2YX3NYPXB3HARW2JOF0&ll=18.9387711,72.8353355&v=20190714&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 2                                                 []    False
# 3  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...    False
# 4                                                 []    False
#
#                          id        location.address location.cc location.city  \
# 0  4e81776030f86985e40abb54   Breach Candy Hospital          IN        Mumbai
# 1  50050da9e4b0d73a8dfa7ee9              One Forbes          IN        Mumbai
# 2  4bdfcc5affdec9286e31eda1           Oxford Towers          IN           NaN
# 3  4e2943f02271752a459cb122                    Fort          IN        Mumbai
# 4  4d53497cd4a6721ec05589ac  Mumbai central station          IN        Mumbai
#
#   location.country location.crossStreet  location.distance  \
# 0            India                  NaN               4874
# 1            India           Kala Ghoda                890
# 2            India                  NaN               1781
# 3            India                  NaN                898
# 4            India                  NaN               3890
#
#                            location.formattedAddress  \
# 0  [Breach Candy Hospital, Mumbai 400026, Mahārās...
# 1  [One Forbes (Kala Ghoda), Mumbai, Mahārāshtra,...
# 2                [Oxford Towers, Mahārāshtra, India]
# 3                 [Fort, Mumbai, Mahārāshtra, India]
# 4  [Mumbai central station, Mumbai, Mahārāshtra, ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 18.97183316652913...     18.971833
# 1  [{'label': 'display', 'lat': 18.930769, 'lng':...     18.930769
# 2  [{'label': 'display', 'lat': 18.922937, 'lng':...     18.922937
# 3  [{'label': 'display', 'lat': 18.93319755884302...     18.933198
# 4  [{'label': 'display', 'lat': 18.97083858982881...     18.970839
#
#    location.lng location.postalCode location.state  \
# 0     72.804981              400026    Mahārāshtra
# 1     72.835434                 NaN    Mahārāshtra
# 2     72.832849                 NaN    Mahārāshtra
# 3     72.829170                 NaN    Mahārāshtra
# 4     72.820636                 NaN    Mahārāshtra
#
#                           name    referralId
# 0                    Cafeteria  v-1563094041
# 1    Cafeteria at Tata Capital  v-1563094041
# 2   Cafeteria at Indian Hotels  v-1563094041
# 3  Mumbai High Court Cafeteria  v-1563094041
# 4                    Cafeteria  v-1563094041

# %% [markdown]
# ## **Clean Cafeteria Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                           name  categories                 address  cc  \
# 0                    Cafeteria        Café   Breach Candy Hospital  IN
# 1    Cafeteria at Tata Capital  Food Court              One Forbes  IN
# 2   Cafeteria at Indian Hotels        None           Oxford Towers  IN
# 3  Mumbai High Court Cafeteria  Food Court                    Fort  IN
# 4                    Cafeteria        None  Mumbai central station  IN
#
#      city country crossStreet  distance  \
# 0  Mumbai   India         NaN      4874
# 1  Mumbai   India  Kala Ghoda       890
# 2     NaN   India         NaN      1781
# 3  Mumbai   India         NaN       898
# 4  Mumbai   India         NaN      3890
#
#                                     formattedAddress  \
# 0  [Breach Candy Hospital, Mumbai 400026, Mahārās...
# 1  [One Forbes (Kala Ghoda), Mumbai, Mahārāshtra,...
# 2                [Oxford Towers, Mahārāshtra, India]
# 3                 [Fort, Mumbai, Mahārāshtra, India]
# 4  [Mumbai central station, Mumbai, Mahārāshtra, ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 18.97183316652913...  18.971833  72.804981
# 1  [{'label': 'display', 'lat': 18.930769, 'lng':...  18.930769  72.835434
# 2  [{'label': 'display', 'lat': 18.922937, 'lng':...  18.922937  72.832849
# 3  [{'label': 'display', 'lat': 18.93319755884302...  18.933198  72.829170
# 4  [{'label': 'display', 'lat': 18.97083858982881...  18.970839  72.820636
#
#   postalCode        state                        id
# 0     400026  Mahārāshtra  4e81776030f86985e40abb54
# 1        NaN  Mahārāshtra  50050da9e4b0d73a8dfa7ee9
# 2        NaN  Mahārāshtra  4bdfcc5affdec9286e31eda1
# 3        NaN  Mahārāshtra  4e2943f02271752a459cb122
# 4        NaN  Mahārāshtra  4d53497cd4a6721ec05589ac

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                         name                 categories  \
# 0                                  Cafeteria                       Café
# 1                  Cafeteria at Tata Capital                 Food Court
# 2                 Cafeteria at Indian Hotels                       None
# 3                Mumbai High Court Cafeteria                 Food Court
# 4                                  Cafeteria                       None
# 5   KES College of Commerce & Arts Cafeteria          College Cafeteria
# 6                   Cafeteria, Lodha Excelus                  Cafeteria
# 7                  Burhani College Cafeteria          College Cafeteria
# 8                    Cafeteria - P2 Building                  Cafeteria
# 9                        Jan Ahaar Cafeteria                      Diner
# 10                          Jai Hind College  College Academic Building
# 11                           Essar Cafeteria                       Food
# 12                             G2W Cafeteria                  Cafeteria
# 13                    Ashok Towers Cafeteria                       Café
# 14                    Adfactors PR Cafeteria                     Buffet
# 15                 Mahindra Towers Cafeteria                  Cafeteria
# 16                     Leo Burnett Cafeteria                  Cafeteria
# 17                           burhani college      College Arts Building
# 18                       welingkar cafeteria                  Cafeteria
# 19        Price Waterhouse Coopers cafeteria                       Café
# 20        Empire Cafeteria (Siddhi caterers)                       Café
# 21                   VIT Executive Cafeteria          College Cafeteria
# 22                             Bloomberg UTV                 Food Court
# 23               Mahindra Holidays Cafeteria                Snack Place
# 24                              BloombergUTV                 Food Court
# 25                         Leo Burnett India                     Office
# 26                         Indigo Consulting                   Building
# 27                                Network 18                     Office
#
#                                               address        lat        lng  \
# 0                               Breach Candy Hospital  18.971833  72.804981
# 1                                          One Forbes  18.930769  72.835434
# 2                                       Oxford Towers  18.922937  72.832849
# 3                                                Fort  18.933198  72.829170
# 4                              Mumbai central station  18.970839  72.820636
# 5                                         Parekh lane  18.948587  72.829424
# 6                           9th Floor, Lodha Excelus,  18.994027  72.834380
# 7                           Opp St Mary's School ICSE  18.964665  72.843831
# 8                            Next to Phoenix Building  18.992866  72.823965
# 9                              Mumbai Central Station  18.975868  72.823434
# 10                                 A Road, Churchgate  18.934689  72.824822
# 11                                                NaN  18.979570  72.819515
# 12                                                NaN  18.974342  72.813182
# 13                                       Ashok Towers  18.997597  72.837888
# 14                                                NaN  19.005008  72.826450
# 15                                              Worli  19.006044  72.820630
# 16                                     36-A Big Apple  18.998785  72.840376
# 17                                           Mazagoan  18.970446  72.835390
# 18                                                NaN  19.025060  72.850341
# 19                                                NaN  19.030498  72.838367
# 20               Empire Mills Compound, Tulsi Pipe Rd  19.000831  72.828339
# 21                Vidyalankar Institute Of Technology  19.021675  72.870364
# 22                                                NaN  18.996877  72.819759
# 23  Mahindra Holidays, Mahindra Towers, G.M. Bhosl...  19.005692  72.822309
# 24            Parijaat House, 1076, Dr. E Moses Road,  18.996397  72.819472
# 25                                                NaN  18.998824  72.840360
# 26                                      The Big Apple  18.998891  72.840350
# 27                New Empire Complex, Lower Parel (w)  19.031835  72.845926
#
#    postalCode        state
# 0      400026  Mahārāshtra
# 1         NaN  Mahārāshtra
# 2         NaN  Mahārāshtra
# 3         NaN  Mahārāshtra
# 4         NaN  Mahārāshtra
# 5      400067  Mahārāshtra
# 6      400011  Mahārāshtra
# 7         NaN  Mahārāshtra
# 8      400013  Mahārāshtra
# 9         NaN          NaN
# 10    400 020  Mahārāshtra
# 11        NaN  Mahārāshtra
# 12        NaN          NaN
# 13        NaN  Mahārāshtra
# 14        NaN          NaN
# 15     400030  Mahārāshtra
# 16     400012  Mahārāshtra
# 17     400010  Mahārāshtra
# 18        NaN          NaN
# 19        NaN          NaN
# 20        NaN  Mahārāshtra
# 21     400037  Mahārāshtra
# 22        NaN          NaN
# 23     400018  Mahārāshtra
# 24     400018  Mahārāshtra
# 25        NaN          NaN
# 26     400012  Mahārāshtra
# 27        NaN  Mahārāshtra

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                         name                 categories  \
# 0                                  Cafeteria                       Café
# 5   KES College of Commerce & Arts Cafeteria          College Cafeteria
# 6                   Cafeteria, Lodha Excelus                  Cafeteria
# 8                    Cafeteria - P2 Building                  Cafeteria
# 10                          Jai Hind College  College Academic Building
# 15                 Mahindra Towers Cafeteria                  Cafeteria
# 16                     Leo Burnett Cafeteria                  Cafeteria
# 17                           burhani college      College Arts Building
# 21                   VIT Executive Cafeteria          College Cafeteria
# 23               Mahindra Holidays Cafeteria                Snack Place
# 24                              BloombergUTV                 Food Court
# 26                         Indigo Consulting                   Building
#
#                                               address        lat        lng  \
# 0                               Breach Candy Hospital  18.971833  72.804981
# 5                                         Parekh lane  18.948587  72.829424
# 6                           9th Floor, Lodha Excelus,  18.994027  72.834380
# 8                            Next to Phoenix Building  18.992866  72.823965
# 10                                 A Road, Churchgate  18.934689  72.824822
# 15                                              Worli  19.006044  72.820630
# 16                                     36-A Big Apple  18.998785  72.840376
# 17                                           Mazagoan  18.970446  72.835390
# 21                Vidyalankar Institute Of Technology  19.021675  72.870364
# 23  Mahindra Holidays, Mahindra Towers, G.M. Bhosl...  19.005692  72.822309
# 24            Parijaat House, 1076, Dr. E Moses Road,  18.996397  72.819472
# 26                                      The Big Apple  18.998891  72.840350
#
#    postalCode        state
# 0      400026  Mahārāshtra
# 5      400067  Mahārāshtra
# 6      400011  Mahārāshtra
# 8      400013  Mahārāshtra
# 10    400 020  Mahārāshtra
# 15     400030  Mahārāshtra
# 16     400012  Mahārāshtra
# 17     400010  Mahārāshtra
# 21     400037  Mahārāshtra
# 23     400018  Mahārāshtra
# 24     400018  Mahārāshtra
# 26     400012  Mahārāshtra

# %% [markdown]
# ## **Search for Shopping Stores**

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IN0FVR5XYV5JDJRQVJMP3BAX0XPFOLWK3LMJ2Z4YH0ZZXLXQ&client_secret=YLE4XQ4ROLZFWWKVMJQABWRM5Q0VG2YX3NYPXB3HARW2JOF0&ll=18.9387711,72.8353355&v=20190714&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 2  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id location.cc location.city location.country  \
# 0  4e54cc34ae60e3d6b7f18c28          IN        Mumbai            India
# 1  527b9fd8498e3c08ce24052d          IN           NaN            India
# 2  4ecf3a6ce5faa5ec01659919          IN           NaN            India
#
#    location.distance     location.formattedAddress  \
# 0                789  [Mumbai, Mahārāshtra, India]
# 1               1106                       [India]
# 2               1180                       [India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 18.94518213019515...     18.945182
# 1  [{'label': 'display', 'lat': 18.9486880047746,...     18.948688
# 2  [{'label': 'display', 'lat': 18.94679133422852...     18.946791
#
#    location.lng location.state                       name    referralId
# 0     72.832121    Mahārāshtra     Ashoka Shopping Centre  v-1563094043
# 1     72.836013            NaN    Ashrafi Shopping Centre  v-1563094043
# 2     72.827999            NaN  Bhangwadi Shopping Arcade  v-1563094043

# %% [markdown]
# ## **Clean Shopping Dataframe**

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                         name categories  cc    city country  distance  \
# 0     Ashoka Shopping Centre     Office  IN  Mumbai   India       789
# 1    Ashrafi Shopping Centre     Office  IN     NaN   India      1106
# 2  Bhangwadi Shopping Arcade     Office  IN     NaN   India      1180
#
#                formattedAddress  \
# 0  [Mumbai, Mahārāshtra, India]
# 1                       [India]
# 2                       [India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 18.94518213019515...  18.945182  72.832121
# 1  [{'label': 'display', 'lat': 18.9486880047746,...  18.948688  72.836013
# 2  [{'label': 'display', 'lat': 18.94679133422852...  18.946791  72.827999
#
#          state                        id
# 0  Mahārāshtra  4e54cc34ae60e3d6b7f18c28
# 1          NaN  527b9fd8498e3c08ce24052d
# 2          NaN  4ecf3a6ce5faa5ec01659919

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                         name categories        lat        lng        state
# 0     Ashoka Shopping Centre     Office  18.945182  72.832121  Mahārāshtra
# 1    Ashrafi Shopping Centre     Office  18.948688  72.836013          NaN
# 2  Bhangwadi Shopping Arcade     Office  18.946791  72.827999          NaN

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2
df_Shopping
# Out:
#                         name categories        lat        lng        state
# 0     Ashoka Shopping Centre     Office  18.945182  72.832121  Mahārāshtra
# 1    Ashrafi Shopping Centre     Office  18.948688  72.836013          NaN
# 2  Bhangwadi Shopping Arcade     Office  18.946791  72.827999          NaN

# %% [markdown]
# ## **Generate map to visualize hotels, shopping stores and Cafeteria and how they cluster together**

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                               address  \
# 0                               Breach Candy Hospital
# 1                                         Parekh lane
# 2                           9th Floor, Lodha Excelus,
# 3                            Next to Phoenix Building
# 4                                  A Road, Churchgate
# 5                                               Worli
# 6                                      36-A Big Apple
# 7                                            Mazagoan
# 8                 Vidyalankar Institute Of Technology
# 9   Mahindra Holidays, Mahindra Towers, G.M. Bhosl...
# 10            Parijaat House, 1076, Dr. E Moses Road,
# 11                                      The Big Apple
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                    categories        lat        lng  \
# 0                        Café  18.971833  72.804981
# 1           College Cafeteria  18.948587  72.829424
# 2                   Cafeteria  18.994027  72.834380
# 3                   Cafeteria  18.992866  72.823965
# 4   College Academic Building  18.934689  72.824822
# 5                   Cafeteria  19.006044  72.820630
# 6                   Cafeteria  18.998785  72.840376
# 7       College Arts Building  18.970446  72.835390
# 8           College Cafeteria  19.021675  72.870364
# 9                 Snack Place  19.005692  72.822309
# 10                 Food Court  18.996397  72.819472
# 11                   Building  18.998891  72.840350
# 12                     Office  18.945182  72.832121
# 13                     Office  18.948688  72.836013
# 14                     Office  18.946791  72.827999
#
#                                         name postalCode        state
# 0                                  Cafeteria     400026  Mahārāshtra
# 1   KES College of Commerce & Arts Cafeteria     400067  Mahārāshtra
# 2                   Cafeteria, Lodha Excelus     400011  Mahārāshtra
# 3                    Cafeteria - P2 Building     400013  Mahārāshtra
# 4                           Jai Hind College    400 020  Mahārāshtra
# 5                  Mahindra Towers Cafeteria     400030  Mahārāshtra
# 6                      Leo Burnett Cafeteria     400012  Mahārāshtra
# 7                            burhani college     400010  Mahārāshtra
# 8                    VIT Executive Cafeteria     400037  Mahārāshtra
# 9                Mahindra Holidays Cafeteria     400018  Mahārāshtra
# 10                              BloombergUTV     400018  Mahārāshtra
# 11                         Indigo Consulting     400012  Mahārāshtra
# 12                    Ashoka Shopping Centre        NaN  Mahārāshtra
# 13                   Ashrafi Shopping Centre        NaN          NaN
# 14                 Bhangwadi Shopping Arcade        NaN          NaN

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **Generate map to visualize Park, Restaurant and Cafeteria and how they cluster together**

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                               address  \
# 0            Breach Candy, Behind American Counsulate
# 1                                  Near GPO, Fort, VT
# 2                                   Veer Nariman Road
# 3                         Palton Road, Near Haj House
# 4   Gaumukh Bhawan, Masjid Bunder West, Near Masji...
# 5                                     opp fort market
# 6                              57 Mahatma Gandhi Road
# 7                                           Mint Road
# 8                                     Horniman Circle
# 9                    Kalaghoda, 145 Mahatma Gandhi Rd
# 10                                    J. D. Tata Road
# 11                          B Block, Sitaram Building
# 12                              Breach Candy Hospital
# 13                                        Parekh lane
# 14                          9th Floor, Lodha Excelus,
# 15                           Next to Phoenix Building
# 16                                 A Road, Churchgate
# 17                                              Worli
# 18                                     36-A Big Apple
# 19                                           Mazagoan
# 20                Vidyalankar Institute Of Technology
# 21  Mahindra Holidays, Mahindra Towers, G.M. Bhosl...
# 22            Parijaat House, 1076, Dr. E Moses Road,
# 23                                      The Big Apple
#
#                        categories           crossStreet        lat        lng  \
# 0                            Park  Bhulabhai Desai Road  18.914867  72.823688
# 1               Indian Restaurant                   NaN  18.937974  72.837663
# 2               Indian Restaurant                   NaN  18.933173  72.826929
# 3               Indian Restaurant                   NaN  18.945343  72.836809
# 4               Indian Restaurant                   NaN  18.953200  72.837577
# 5                            Food                   NaN  18.935112  72.836896
# 6               Indian Restaurant                   NaN  18.931366  72.831462
# 7                       BBQ Joint                   NaN  18.935266  72.837240
# 8              Mughlai Restaurant                   NaN  18.931330  72.834983
# 9               Indian Restaurant                   NaN  18.928134  72.831541
# 10  Vegetarian / Vegan Restaurant                   NaN  18.930674  72.826320
# 11                         Lounge                   NaN  18.945482  72.834270
# 12                           Café                   NaN  18.971833  72.804981
# 13              College Cafeteria                   NaN  18.948587  72.829424
# 14                      Cafeteria                   NaN  18.994027  72.834380
# 15                      Cafeteria                   NaN  18.992866  72.823965
# 16      College Academic Building                   NaN  18.934689  72.824822
# 17                      Cafeteria                   NaN  19.006044  72.820630
# 18                      Cafeteria                   NaN  18.998785  72.840376
# 19          College Arts Building                   NaN  18.970446  72.835390
# 20              College Cafeteria                   NaN  19.021675  72.870364
# 21                    Snack Place                   NaN  19.005692  72.822309
# 22                     Food Court                   NaN  18.996397  72.819472
# 23                       Building                   NaN  18.998891  72.840350
#
#                                           name postalCode        state
# 0              Harish Mahindra Children's Park     400026  Mahārāshtra
# 1            Nanumal Bhojraj Restaurant - Fort     400001  Mahārāshtra
# 2                  Stadium Restaurant & Stores     400023  Mahārāshtra
# 3                         Iran Like Restaurant     400001  Mahārāshtra
# 4   Nanumal Bhojraj Restaurant - Masjid Bunder     400009  Mahārāshtra
# 5                          National Restaurant     400001  Mahārāshtra
# 6                 Fountain Sizzlers Restaurant    400 023  Mahārāshtra
# 7                       Excellensea Restaurant     400001  Mahārāshtra
# 8                Bademiya The Kabab Restaurant     400002  Mahārāshtra
# 9                            Khyber Restaurant    400 023  Mahārāshtra
# 10                       Samrat Veg Restaurant    400 020  Mahārāshtra
# 11                          Ustaadi Restaurant     400001  Mahārāshtra
# 12                                   Cafeteria     400026  Mahārāshtra
# 13    KES College of Commerce & Arts Cafeteria     400067  Mahārāshtra
# 14                    Cafeteria, Lodha Excelus     400011  Mahārāshtra
# 15                     Cafeteria - P2 Building     400013  Mahārāshtra
# 16                            Jai Hind College    400 020  Mahārāshtra
# 17                   Mahindra Towers Cafeteria     400030  Mahārāshtra
# 18                       Leo Burnett Cafeteria     400012  Mahārāshtra
# 19                             burhani college     400010  Mahārāshtra
# 20                     VIT Executive Cafeteria     400037  Mahārāshtra
# 21                 Mahindra Holidays Cafeteria     400018  Mahārāshtra
# 22                                BloombergUTV     400018  Mahārāshtra
# 23                           Indigo Consulting     400012  Mahārāshtra

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
